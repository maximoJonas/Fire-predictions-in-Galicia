# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pprint 
import requests
import time
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Sacamos datos de la API AEMET para coger todas las estaciones

# %%
apiKey="eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4"

# %%
url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/"

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4"}

headers = {
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/4a25da46",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/0556af7a"
# }

# %%
url=response.json()["datos"]
url
# Out:
# 'https://opendata.aemet.es/opendata/sh/4a25da46'

# %%
response = requests.get(url)
print(response.text)
# Out:
# [ {
#   "latitud" : "413515N",
#   "provincia" : "BARCELONA",
#   "altitud" : "74",
#   "indicativo" : "0252D",
#   "nombre" : "ARENYS DE MAR",
#   "indsinop" : "08186",
#   "longitud" : "023224E"
# }, {
#   "latitud" : "411734N",
#   "provincia" : "BARCELONA",
#   "altitud" : "4",
#   "indicativo" : "0076",
#   "nombre" : "BARCELONA AEROPUERTO",
#   "indsinop" : "08181",
#   "longitud" : "020412E"
# }, {
#   "latitud" : "412506N",
#   "provincia" : "BARCELONA",
#   "altitud" : "408",
#   "indicativo" : "0200E",
#   "nombre" : "BARCELONA, FABRA",
#   "indsinop" : "",
#   "longitud" : "020727E"
# }, {
#   "latitud" : "412326N",
#   "provincia" : "BARCELONA",
#   "altitud" : "6",
#   "indicativo" : "0201D",
#   "nombre" : "BARCELONA",
#   "indsinop" : "08180",
#   "longitud" : "021200E"
# }, {
#   "latitud" : "414312N",
#   "provincia" : "BARCELONA",
#   "altitud" : "291",
#   "indicativo" : "0149X",
#   "nombre" : "MANRESA",
#   "indsinop" : "08174",
#   "longitud" : "015025E"
# }, {
# ...

# %%
df_estaciones=pd.DataFrame.from_dict(response.json())
df_estaciones
# Out:
#      latitud              provincia altitud indicativo  \
# 0    413515N              BARCELONA      74      0252D
# 1    411734N              BARCELONA       4       0076
# 2    412506N              BARCELONA     408      0200E
# 3    412326N              BARCELONA       6      0201D
# 4    414312N              BARCELONA     291      0149X
# ..       ...                    ...     ...        ...
# 286  280523N  STA. CRUZ DE TENERIFE      15      C329Z
# 287  282748N  STA. CRUZ DE TENERIFE      35      C449C
# 288  283545N  STA. CRUZ DE TENERIFE      62      C129Z
# 289  282839N  STA. CRUZ DE TENERIFE     632      C447A
# 290  280249N  STA. CRUZ DE TENERIFE      64      C429I
#
#                          nombre indsinop longitud
# 0                 ARENYS DE MAR    08186  023224E
# 1          BARCELONA AEROPUERTO    08181  020412E
# 2              BARCELONA, FABRA           020727E
# 3                     BARCELONA    08180  021200E
# ...

# %%
df_estaciones_Gal=df_estaciones[(df_estaciones["provincia"]=="PONTEVEDRA") | (df_estaciones["provincia"]=="A CORUÑA") | (df_estaciones["provincia"]=="OURENSE") | (df_estaciones["provincia"]=="LUGO")]

# %%
# Borramos 2 estaciones sin datos

df_estaciones_Gal=df_estaciones_Gal.drop([57,60])

df_estaciones_Gal
# Out:
#     latitud   provincia altitud indicativo                             nombre  \
# 13  431825N    A CORUÑA      98      1387E                A CORUÑA AEROPUERTO
# 14  432157N    A CORUÑA      58       1387                           A CORUÑA
# 15  430938N    A CORUÑA      50       1393                         CABO VILÁN
# 16  434710N    A CORUÑA      90       1351                    ESTACA DE BARES
# 17  425529N    A CORUÑA     230       1400                           FISTERRA
# 18  424314N    A CORUÑA     685      1437O                       MONTE IROITE
# 19  424418N    A CORUÑA     100      1473A                             PADRÓN
# 20  425317N    A CORUÑA     370       1428  SANTIAGO DE COMPOSTELA AEROPUERTO
# 21  425234N    A CORUÑA     240      1475X             SANTIAGO DE COMPOSTELA
# 53  430641N        LUGO     445       1505                    LUGO AEROPUERTO
# 55  422022N     OURENSE     840      1631E                  A POBRA DE TRIVES
# ...

# %%
# creamos un id 

lista_num=[]
for i in range(len(df_estaciones_Gal["indicativo"])):
    lista_num.append(i)

df_estaciones_Gal["id"]=lista_num

# %% [markdown]
# # Sacamos datos de la API  AEMET de cada estación

# %% [markdown]
# https://opendata.aemet.es/dist/index.html?

# %%
lista_estaciones=[]
df_data=pd.DataFrame()
año_inicio=2001
año_fin=2005

for fechas in range(3):
    
    for indicativ in df_estaciones_Gal["indicativo"]:
        print(año_inicio,año_fin)
        url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{año_inicio}-01-01T00:00:00UTC/fechafin/{año_fin}-12-31T23:59:59UTC/estacion/{indicativ}"
        print(url)
        querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4"}

        headers = {'cache-control': "no-cache" }
        print(indicativ)
        response = requests.request("GET", url, headers=headers, params=querystring)
        print(response.json())
        url=response.json()["datos"]
        print(url)
        response_url = requests.get(url)
        lista_estaciones.append(response_url)
        
        time.sleep(5)
        
        
    año_fin+=5
    año_inicio+=5
# Out:
# 2001 2005
# https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-01-01T00:00:00UTC/fechafin/2005-12-31T23:59:59UTC/estacion/1387E
# 1387E
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/713bddd7', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# https://opendata.aemet.es/opendata/sh/713bddd7
# 2001 2005
# https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-01-01T00:00:00UTC/fechafin/2005-12-31T23:59:59UTC/estacion/1387
# 1387
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/d7da7410', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# https://opendata.aemet.es/opendata/sh/d7da7410
# 2001 2005
# https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2001-01-01T00:00:00UTC/fechafin/2005-12-31T23:59:59UTC/estacion/1393
# 1393
# ...

# %%
for estac in lista_estaciones:
    df_es=pd.DataFrame.from_dict(estac.json())
    df_data=pd.concat([df_data,df_es])
    
    
df_data
# Out:
#            fecha indicativo               nombre   provincia altitud  tmed  \
# 0     2001-01-01      1387E  A CORUÑA AEROPUERTO    A CORUÑA      98  12,0
# 1     2001-01-02      1387E  A CORUÑA AEROPUERTO    A CORUÑA      98   9,8
# 2     2001-01-03      1387E  A CORUÑA AEROPUERTO    A CORUÑA      98  11,8
# 3     2001-01-04      1387E  A CORUÑA AEROPUERTO    A CORUÑA      98  12,4
# 4     2001-01-05      1387E  A CORUÑA AEROPUERTO    A CORUÑA      98  12,4
# ...          ...        ...                  ...         ...     ...   ...
# 1821  2015-12-27       1495      VIGO AEROPUERTO  PONTEVEDRA     255  12,6
# 1822  2015-12-28       1495      VIGO AEROPUERTO  PONTEVEDRA     255   NaN
# 1823  2015-12-29       1495      VIGO AEROPUERTO  PONTEVEDRA     255  11,2
# 1824  2015-12-30       1495      VIGO AEROPUERTO  PONTEVEDRA     255  11,0
# 1825  2015-12-31       1495      VIGO AEROPUERTO  PONTEVEDRA     255  10,2
#
# ...

# %% [markdown]
# # Añadimos las columnas Year, Month y Day de la columna fecha

# %%
df_data["fecha"]=pd.to_datetime(df_data["fecha"])

# %%
df_data["Year"]=pd.DatetimeIndex(df_data["fecha"]).year
df_data["Month"]=pd.DatetimeIndex(df_data["fecha"]).month
df_data["Day"]=pd.DatetimeIndex(df_data["fecha"]).day

# %% [markdown]
# # Lo guardamos en un csv

# %%
df_data.to_csv("df_data.csv", index = False)

# %% [markdown]
# # Humedad relativa de AEMET. Le añadimos más datos

# %%
import requests
lista_estaciones_hr=[]
df_data=pd.DataFrame()
año=2001


for x in range(14):
    
    for indicativ in df_estaciones_Gal["indicativo"]:
        print(año)
        
        
        url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/{año}/aniofin/{año}/estacion/{indicativ}/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4"
        print(url)
        querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4"}

        headers = {'cache-control': "no-cache" }
        print(indicativ)
        response = requests.request("GET", url, headers=headers, params=querystring)
        print(response.json())
        
        if response.json()["estado"]== 200:
            
            url=response.json()["datos"]
            print(url)
            response_url = requests.get(url)
            lista_estaciones_hr.append(response_url)
        
        time.sleep(5)
        
    año+=1
# Out:
# 2001
# https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/2001/aniofin/2001/estacion/1387E/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4
# 1387E
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/4a2ba7c9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/997c0034'}
# https://opendata.aemet.es/opendata/sh/4a2ba7c9
# 2001
# ...

# %%
df_hr=pd.DataFrame()
for estac in lista_estaciones_hr:
    df_es_hr=pd.DataFrame.from_dict(estac.json())
    df_hr=pd.concat([df_hr,df_es_hr])
df_hr
# Out:
#       fecha indicativo         p_max  n_cub    hr n_gra  n_fog inso  \
# 0    2001-1      1387E      31.8(04)   13.0  82.0   2.0    7.0  1.9
# 1    2001-2      1387E      28.2(05)    5.0  73.0   3.0    6.0  5.7
# 2    2001-3      1387E      45.4(02)   21.0  80.0   0.0    6.0  2.3
# 3    2001-4      1387E       8.4(29)    6.0  71.0   2.0    5.0  6.8
# 4    2001-5      1387E      48.9(01)    6.0  73.0   0.0    8.0  7.6
# ..      ...        ...           ...    ...   ...   ...    ...  ...
# 8    2014-9       1495      51.7(17)   11.0  78.0   0.0    9.0  4.7
# 9   2014-10       1495      73.7(16)   10.0  82.0   0.0   12.0  3.7
# 10  2014-11       1495      57.2(03)   15.0  90.0   0.0   19.0  1.8
# 11  2014-12       1495      36.2(12)   10.0  85.0   0.0    9.0  2.7
# 12  2014-13       1495  73.7(16/oct)  144.0  79.0   0.0  146.0  4.4
#
#              q_max nw_55  ... tm_mes tm_max nv_0100          q_min np_010  \
# 0       1017.1(31)  13.0  ...   10.0   12.7     0.0      981.8(01)   24.0
# ...

# %%
# La fila  12 se refiere a una  media anual que no queremos en nuestros datos
df_hr=df_hr.drop(12)

# %%
df_hr["fecha"]=pd.to_datetime(df_hr["fecha"])

# Separamos año y mes para poder concatenar los datos

df_hr["Year"]=pd.DatetimeIndex(df_hr["fecha"]).year
df_hr["Month"]=pd.DatetimeIndex(df_hr["fecha"]).month
df_hr["Day"]=pd.DatetimeIndex(df_hr["fecha"]).day

# %%
# Guardamos
df_hr.to_csv("df_hr.csv", index = False)

# %% [markdown]
# # API METEOGALICIA (no valian los datos)

# %%
# API_KEY = skqoVttGbRtAPvoq6a92617YZfYxEMbn3eB11G9msyO2G4Efzu7i2cKkC2rqe59i

# %%
# https://servizos.meteogalicia.gal/apiv4/findPlaces?location=oure&API_KEY
#No vale no nos dan los datos que neceistamos tal y como hemos planteado resolver el problema

loc=["oure","lugo","ponte","coru"]

for l in loc:
    url=f"https://servizos.meteogalicia.gal/apiv4/findPlaces?location={loc}&API_KEY=skqoVttGbRtAPvoq6a92617YZfYxEMbn3eB11G9msyO2G4Efzu7i2cKkC2rqe59i"
    response = requests.get(url)


    pprint.pprint(response.json())
    break
# Out:
# {'crs': {'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'},
#          'type': 'name'},
#  'features': [{'geometry': {'coordinates': [-8.38225, 43.34695],
#                             'type': 'Point'},
#                'properties': {'id': '1001302',
#                               'municipality': 'CORUÑA (A)',
#                               'name': 'Praia de Oza',
#                               'province': 'A Coruña',
#                               'type': 'beach'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-8.39505, 43.38109],
#                             'type': 'Point'},
#                'properties': {'id': '1001471',
#                               'municipality': 'CORUÑA (A)',
#                               'name': 'Praia de San Amaro',
#                               'province': 'A Coruña',
#                               'type': 'beach'},
#                'type': 'Feature'},
# ...

# %%
#################################  HR y Temp diarias  ############################################

# %%
url="https://servizos.meteogalicia.gal/apiv4/getNumericForecastInfo?coords=-8,44&variables=temperature,relative_humidity,precipitation_amount&API_KEY=skqoVttGbRtAPvoq6a92617YZfYxEMbn3eB11G9msyO2G4Efzu7i2cKkC2rqe59i"

response = requests.request("GET", url)

print(response.text)
# Out:
# {"type":"FeatureCollection","crs":{"type":"name","properties":{"name":"urn:ogc:def:crs:OGC:1.3:CRS84"}},"features":[{"type":"Feature","geometry":{"type":"Point","coordinates":[-8,44]},"properties":{"days":[{"timePeriod":{"begin":{"timeInstant":"2023-01-22T11:10:32+01"},"end":{"timeInstant":"2023-01-22T23:59:59+01"}},"variables":[{"name":"temperature","model":"WRF","grid":"04km","units":"degc","geometry":{"type":"Point","coordinates":[-8,44]},"values":[{"timeInstant":"2023-01-22T12:00:00+01","modelRun":"2023-01-22T01:00:00+01","value":11},{"timeInstant":"2023-01-22T13:00:00+01","modelRun":"2023-01-22T01:00:00+01","value":11},{"timeInstant":"2023-01-22T14:00:00+01","modelRun":"2023-01-22T01:00:00+01","value":11},{"timeInstant":"2023-01-22T15:00:00+01","modelRun":"2023-01-22T01:00:00+01","value":11},{"timeInstant":"2023-01-22T16:00:00+01","modelRun":"2023-01-22T01:00:00+01","value":11},{"timeInstant":"2023-01-22T17:00:00+01","modelRun":"2023-01-22T01:00:00+01","value":11},{"timeInstant"
# ...

# %%
dic=response.json()
dic["features"]
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8, 44]},
#   'properties': {'days': [{'timePeriod': {'begin': {'timeInstant': '2023-01-22T11:10:32+01'},
#       'end': {'timeInstant': '2023-01-22T23:59:59+01'}},
#      'variables': [{'name': 'temperature',
#        'model': 'WRF',
#        'grid': '04km',
#        'units': 'degc',
#        'geometry': {'type': 'Point', 'coordinates': [-8, 44]},
#        'values': [{'timeInstant': '2023-01-22T12:00:00+01',
#          'modelRun': '2023-01-22T01:00:00+01',
#          'value': 11},
#         {'timeInstant': '2023-01-22T13:00:00+01',
#          'modelRun': '2023-01-22T01:00:00+01',
#          'value': 11},
#         {'timeInstant': '2023-01-22T14:00:00+01',
#          'modelRun': '2023-01-22T01:00:00+01',
#          'value': 11},
#         {'timeInstant': '2023-01-22T15:00:00+01',
#          'modelRun': '2023-01-22T01:00:00+01',
#          'value': 11},
#         {'timeInstant': '2023-01-22T16:00:00+01',
# ...

# %%
dic["features"][0]["properties"]["days"][0]["variables"]
# Out:
# [{'name': 'temperature',
#   'model': 'WRF',
#   'grid': '04km',
#   'units': 'degc',
#   'geometry': {'type': 'Point', 'coordinates': [-8, 44]},
#   'values': [{'timeInstant': '2023-01-22T12:00:00+01',
#     'modelRun': '2023-01-22T01:00:00+01',
#     'value': 11},
#    {'timeInstant': '2023-01-22T13:00:00+01',
#     'modelRun': '2023-01-22T01:00:00+01',
#     'value': 11},
#    {'timeInstant': '2023-01-22T14:00:00+01',
#     'modelRun': '2023-01-22T01:00:00+01',
#     'value': 11},
#    {'timeInstant': '2023-01-22T15:00:00+01',
#     'modelRun': '2023-01-22T01:00:00+01',
#     'value': 11},
#    {'timeInstant': '2023-01-22T16:00:00+01',
#     'modelRun': '2023-01-22T01:00:00+01',
#     'value': 11},
#    {'timeInstant': '2023-01-22T17:00:00+01',
#     'modelRun': '2023-01-22T01:00:00+01',
#     'value': 11},
#    {'timeInstant': '2023-01-22T18:00:00+01',
#     'modelRun': '2023-01-22T01:00:00+01',
#     'value': 11},
#    {'timeInstant': '2023-01-22T19:00:00+01',
# ...

# %% [markdown]
# # Pedimos a la API Meteosat datos de los siguientes días para predecir y preparamos los datos para la predicción

# %%
# Leemos y preparamos para unir los ids con la otra tabla
# df_codigos_ema=pd.read_excel("codigos emas y concellos.xlsx")
# Preparamos la tabla de codigos con la de ID para hacer un merge de las 2

# df_codigos_ema["codigo concello"]=df_codigos_ema["codigo concello"].astype(int)
# df_codigos_ema["Identificador"]=df_codigos_ema["Identificador"].astype(str)
# df_codigos_ema

# cambiamos valor debido a que habia salido un caracter  a mayores y estaba mal

# df_codigos_ema["Identificador"][12]="1690A"

# df_id["indicativo"]=df_id["indicativo"].astype(str)

# Unimos los codigos de municipio a nuestra tabbla 

# df_codigos_ema=pd.merge(left=df_id,right=df_codigos_ema,left_on="indicativo",right_on="Identificador")

# df_codigos_ema.drop(columns="Identificador",inplace=True)

# %%
df_codigos_ema.to_excel("codigos emas y concellos.xlsx",index=False)

# %% [markdown]
# # Pedimos a  la API que nos de los datos de predicción para los municipios

# %%
#lAS PREDICCIONES SON MUY POBRES LOS DATOS QUE NOS DAN E INSUFICIENTES PARA HACER UNA PREDICCION FIABLE
# Se podrian ver otras APIS para completar datos

def inc_pred_municipios():
    
    df_codigos_ema=pd.read_excel("codigos emas y concellos.xlsx")  
    # Preparamos la tabla de codigos con la de ID para hacer un merge de las 2

#     df_codigos_ema["codigo concello"]=df_codigos_ema["codigo concello"].astype(int)
#     df_codigos_ema["Identificador"]=df_codigos_ema["Identificador"].astype(str)

    # cambiamos valor debido a que habia salido un caracter  a mayores y estaba mal

#     df_codigos_ema["Identificador"][12]="1690A"

#     df_id["indicativo"]=df_id["indicativo"].astype(str)

    # Unimos los codigos de municipio a nuestra tabbla 

#     df_codigos_ema=pd.merge(left=df_id,right=df_codigos_ema,left_on="indicativo",right_on="Identificador")

#     df_codigos_ema.drop(columns="Identificador",inplace=True)
    
#     df_codigos_ema.to_excel("codigos emas y concellos.xlsx",index=False)
    

    # por cada cconcello nos devuelve los 4 siguientes días
    lista_estaciones,lista_ID,lista_municipio=[],[],[]
    lista_pred=[]
    df_data=pd.DataFrame()
    df_pc=pd.DataFrame()

    for idMunicipio in df_codigos_ema["codigo concello"]:

        url = f"https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/diaria/{idMunicipio}"
        print(url)
        querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4"}

        headers = {'cache-control': "no-cache" }
       
        response = requests.request("GET", url, headers=headers, params=querystring)
    
          
        if response.json()["estado"]== 200:  
            url=response.json()["datos"]
            print(url)
            response_url = requests.get(url)
            lista_estaciones.append(response_url)
            lista_ID.append(idMunicipio)
            print(response_url)
        time.sleep(2)

    x=0
    for estac in lista_estaciones:

        df_es=pd.DataFrame.from_dict(estac.json()[0]["prediccion"]["dia"])
        df_es["ID"]=lista_ID[x]
        df_pc=pd.concat([df_pc,df_es[:4]])
        print("+"*50)
        print("x= ",x)
        print("listaID=",lista_ID[x])
        display(df_es)
        x+=1

    # df_pc=pd.DataFrame.from_dict(lista_estaciones[0].json()[0]["prediccion"]["dia"])
    df_pc.reset_index(drop=True,inplace=True)
    display(df_pc)

    df_pc["fecha"]=pd.to_datetime(df_pc["fecha"])


    # df_pc["ID"]=df_codigos_ema[df_codigos_ema["codigo concello"]==idM]["ID"][0]
    # print(idM)
    # display(df_pc)

    for i in range(len(df_pc)):

        val=int(df_pc.iloc[i]["probPrecipitacion"][0]["value"])
        if  val >10:
            val=1
        else:
            val=0


        viento=df_pc.iloc[i]["viento"][0]["velocidad"]
        t_max=df_pc.iloc[i]["temperatura"]["maxima"]
        t_min=df_pc.iloc[i]["temperatura"]["minima"]
        tmed=(t_max+t_min)/2
        hr=(df_pc.iloc[i]["humedadRelativa"]["maxima"]+df_pc.iloc[i]["humedadRelativa"]["minima"])/2


        Year=pd.DatetimeIndex(df_pc["fecha"]).year[i]
        Month=pd.DatetimeIndex(df_pc["fecha"]).month[i]
        Day=pd.DatetimeIndex(df_pc["fecha"]).day[i]

        ID=df_pc.iloc[i]["ID"]
        ID=df_codigos_ema[df_codigos_ema["codigo concello"]==ID]["ID"]
        if len(ID)==1:
            ID=int(ID)
        else:
            ID=int(ID[0])

        lista_pred.append([tmed,val,t_min,t_max,viento,Day,Year,Month,hr,ID])

    df_pc=pd.DataFrame(data=lista_pred,columns=["tmed","probPrecipitacion","temperatura.minima","temperatura.maxima","viento","Day","Year","Month","humedadRelativa.minima","ID_y"])
    display(df_pc)

    df_pc.to_csv("df_pc1.csv", index = False)

# %%
inc_pred_municipios()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 inc_pred_municipios()
#
# NameError: name 'inc_pred_municipios' is not defined

# %%
df_codigos_ema=pd.read_excel("codigos emas y concellos.xlsx")

lista_estaciones,lista_ID=[],[]
df_data=pd.DataFrame()
df_pc=pd.DataFrame()
lista_pred=[]

idMunicipio=[15030,36038]

for idM in idMunicipio: 
    url = f"https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/diaria/{idM}"
    print(url)
    querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqb25hc2RpYXpjaW1hQGdtYWlsLmNvbSIsImp0aSI6ImJkZThjMTg2LTA1MGQtNGFlOS1iZDI1LWNlZDU2ZmY2YWE1YiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjcyODQ5Nzg0LCJ1c2VySWQiOiJiZGU4YzE4Ni0wNTBkLTRhZTktYmQyNS1jZWQ1NmZmNmFhNWIiLCJyb2xlIjoiIn0.G2pN7UvRysSQ1Vvpdz6c_VV-1-OP6GfkMBXRioOnew4"}
    headers = {'cache-control': "no-cache" }

    response = requests.request("GET", url, headers=headers, params=querystring)
    print(response.json())
    
    if response.json()["estado"]== 200:  
        url=response.json()["datos"]
        print(url)
        response_url = requests.get(url)
        lista_estaciones.append(response_url)
        lista_ID.append(idM)
        print(response_url)
#     sleep(3)

x=0
for estac in lista_estaciones:
    
    df_es=pd.DataFrame.from_dict(estac.json()[0]["prediccion"]["dia"])
    df_es["ID"]=lista_ID[x]
    df_pc=pd.concat([df_pc,df_es[:4]])
    x+=1
    
# df_pc=pd.DataFrame.from_dict(lista_estaciones[0].json()[0]["prediccion"]["dia"])
df_pc.reset_index(drop=True,inplace=True)
display(df_pc)

df_pc["fecha"]=pd.to_datetime(df_pc["fecha"])


# df_pc["ID"]=df_codigos_ema[df_codigos_ema["codigo concello"]==idM]["ID"][0]
# print(idM)
# display(df_pc)

    
for i in range(len(df_pc)):
    
    val=int(df_pc.iloc[i]["probPrecipitacion"][0]["value"])
    if  val >10:
        val=1
    else:
        val=0


    viento=df_pc.iloc[i]["viento"][0]["velocidad"]
    t_max=df_pc.iloc[i]["temperatura"]["maxima"]
    t_min=df_pc.iloc[i]["temperatura"]["minima"]
    tmed=(t_max+t_min)/2
    hr=(df_pc.iloc[i]["humedadRelativa"]["maxima"]+df_pc.iloc[i]["humedadRelativa"]["minima"])/2


    Year=pd.DatetimeIndex(df_pc["fecha"]).year[i]
    Month=pd.DatetimeIndex(df_pc["fecha"]).month[i]
    Day=pd.DatetimeIndex(df_pc["fecha"]).day[i]
    
    ID=df_pc.iloc[i]["ID"]
    ID=df_codigos_ema[df_codigos_ema["codigo concello"]==ID]["ID"]
    if len(ID)==1:
        ID=int(ID)
    else:
        ID=int(ID[0])

    lista_pred.append([tmed,val,t_min,t_max,viento,Day,Year,Month,hr,ID])
    
df_pc=pd.DataFrame(data=lista_pred,columns=["tmed","probPrecipitacion","temperatura.minima","temperatura.maxima","viento","Day","Year","Month","humedadRelativa.minima","ID_y"])
display(df_pc)



# tmed,probPrecipitacion,temperatura.minima,temperatura.maxima,viento,Day,Year,Month,humedadRelativa.minima,ID_y
# Out:
# https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/diaria/15030
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a8aa8612', 'metadatos': 'https://opendata.aemet.es/opendata/sh/dfd88b22'}
# https://opendata.aemet.es/opendata/sh/a8aa8612
# <Response [200]>
# https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/diaria/36038
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/530f1286', 'metadatos': 'https://opendata.aemet.es/opendata/sh/dfd88b22'}
# https://opendata.aemet.es/opendata/sh/530f1286
# <Response [200]>
#                                    probPrecipitacion  \
# 0  [{'value': 100, 'periodo': '00-24'}, {'value':...
# 1  [{'value': 90, 'periodo': '00-24'}, {'value': ...
# 2  [{'value': 0, 'periodo': '00-24'}, {'value': 0...
# 3  [{'value': 5, 'periodo': '00-24'}, {'value': 0...
# 4  [{'value': 0, 'periodo': '00-24'}, {'value': 0...
# ...

# %%
df_codigos_ema
# Out:
#     ID indicativo                  Nombre   Provincia Altitud  Latitud  \
# 0    0      1387E     A CORUÑA AEROPUERTO    A CORUÑA   98 m.  431825N
# 1    1       1387                A CORUÑA    A CORUÑA   58 m.  432157N
# 2    2       1393              CABO VILÁN    A CORUÑA   50 m.  430938N
# 3    3       1351         ESTACA DE BARES    A CORUÑA   90 m.  434710N
# 4    4       1400                FISTERRA    A CORUÑA  230 m.  425529N
# 5    5      1437O            MONTE IROITE    A CORUÑA  685 m.  424314N
# 6    6      1473A                  PADRÓN    A CORUÑA  100 m.  424418N
# 7    7       1428     SANTIAGO AEROPUERTO    A CORUÑA  370 m.  425317N
# 8    8      1475X  SANTIAGO DE COMPOSTELA    A CORUÑA  240 m.  425234N
# 9    9       1505         LUGO AEROPUERTO        LUGO  445 m.  430641N
# 10  10      1631E       A POBRA DE TRIVES     OURENSE  840 m.  422022N
# 11  11      1700X            O CARBALLIÑO     OURENSE  400 m.  422517N
# ...
